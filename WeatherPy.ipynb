# %% [markdown]
# # Create Latitude and Longitude Combinations

# %%
# Import the dependencies.
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitudes and longitude combinations.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 616

# %% [markdown]
# # Import Dependencies, and Initialize an Empty List and Counters

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counter.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %% [markdown]
# # Loop Through the List of Cities and Build the City URL

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60) # Pause for 60 seconds.
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | siverek
# Processing Record 2 of Set 1 | aklavik
# Processing Record 3 of Set 1 | oswego
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | husavik
# Processing Record 12 of Set 1 | kulunda
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | dwarka
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | dutlwe
# Processing Record 19 of Set 1 | bandarbeyla
# Processing Record 20 of Set 1 | harsin
# Processing Record 21 of Set 1 | port augusta
# Processing Record 22 of Set 1 | norman wells
# Processing Record 23 of Set 1 | qaanaaq
# Processing Record 24 of Set 1 | araouane
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | severo-kurilsk
# Processing Record 27 of Set 1 | miguel calmon
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | fairbanks
# Processing Record 30 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 1 | muros
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | melilla
# Processing Record 34 of Set 1 | tura
# Processing Record 35 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 1 | kavaratti
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | ponta do sol
# Processing Record 39 of Set 1 | avarua
# Processing Record 40 of Set 1 | waitara
# Processing Record 41 of Set 1 | mount gambier
# Processing Record 42 of Set 1 | pangkalanbuun
# Processing Record 43 of Set 1 | bulgan
# Processing Record 44 of Set 1 | emerald
# Processing Record 45 of Set 1 | cayenne
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | luanda
# Processing Record 50 of Set 1 | kochevo
# Processing Record 1 of Set 2 | mao
# Processing Record 2 of Set 2 | provideniya
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | belaya gora
# Processing Record 5 of Set 2 | kavieng
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | magdalena
# Processing Record 9 of Set 2 | slavyanka
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | nokaneng
# Processing Record 12 of Set 2 | lavrentiya
# Processing Record 13 of Set 2 | kahului
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | abu jubayhah
# City not found. Skipping...
# Processing Record 16 of Set 2 | saint-philippe
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | kendari
# Processing Record 19 of Set 2 | sorland
# Processing Record 20 of Set 2 | yellowknife
# Processing Record 21 of Set 2 | pisco
# Processing Record 22 of Set 2 | krasnoselkup
# Processing Record 23 of Set 2 | bathsheba
# Processing Record 24 of Set 2 | tongliao
# Processing Record 25 of Set 2 | guerrero negro
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | kalmunai
# Processing Record 28 of Set 2 | cabo san lucas
# Processing Record 29 of Set 2 | grand gaube
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | winslow
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | vila franca do campo
# Processing Record 34 of Set 2 | bam
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | alyangula
# Processing Record 37 of Set 2 | sambava
# Processing Record 38 of Set 2 | rawson
# Processing Record 39 of Set 2 | lodja
# Processing Record 40 of Set 2 | sistranda
# Processing Record 41 of Set 2 | canon city
# Processing Record 42 of Set 2 | constitucion
# Processing Record 43 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 2 | port hardy
# Processing Record 45 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 2 | moses lake
# Processing Record 47 of Set 2 | midland
# Processing Record 48 of Set 2 | lorengau
# Processing Record 49 of Set 2 | puerto ayora
# Processing Record 50 of Set 2 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 1 of Set 3 | atuona
# Processing Record 2 of Set 3 | devils lake
# Processing Record 3 of Set 3 | warri
# Processing Record 4 of Set 3 | tuktoyaktuk
# Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 3 | goianesia
# Processing Record 7 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 3 | punta alta
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | kutum
# Processing Record 11 of Set 3 | thunder bay
# Processing Record 12 of Set 3 | chokurdakh
# Processing Record 13 of Set 3 | matiri
# Processing Record 14 of Set 3 | ponta delgada
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 3 | pau
# Processing Record 18 of Set 3 | eyl
# Processing Record 19 of Set 3 | palu
# Processing Record 20 of Set 3 | sinnamary
# Processing Record 21 of Set 3 | talas
# Processing Record 22 of Set 3 | providencia
# Processing Record 23 of Set 3 | grindavik
# Processing Record 24 of Set 3 | san quintin
# Processing Record 25 of Set 3 | dikson
# Processing Record 26 of Set 3 | iqaluit
# Processing Record 27 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 3 | manuk mangkaw
# Processing Record 29 of Set 3 | angoche
# Processing Record 30 of Set 3 | kuusamo
# Processing Record 31 of Set 3 | fortuna
# Processing Record 32 of Set 3 | esperance
# Processing Record 33 of Set 3 | groningen
# Processing Record 34 of Set 3 | brandenburg
# Processing Record 35 of Set 3 | loikaw
# Processing Record 36 of Set 3 | longyearbyen
# Processing Record 37 of Set 3 | ribeira grande
# Processing Record 38 of Set 3 | roebourne
# Processing Record 39 of Set 3 | brae
# Processing Record 40 of Set 3 | tyumentsevo
# Processing Record 41 of Set 3 | broome
# Processing Record 42 of Set 3 | marsa matruh
# Processing Record 43 of Set 3 | touros
# Processing Record 44 of Set 3 | beidao
# Processing Record 45 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 3 | gimli
# Processing Record 47 of Set 3 | berlevag
# Processing Record 48 of Set 3 | newport
# Processing Record 49 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 3 | dolinsk
# Processing Record 1 of Set 4 | comodoro rivadavia
# Processing Record 2 of Set 4 | luderitz
# Processing Record 3 of Set 4 | coihaique
# Processing Record 4 of Set 4 | tornio
# Processing Record 5 of Set 4 | sitka
# Processing Record 6 of Set 4 | berdigestyakh
# Processing Record 7 of Set 4 | mixtequilla
# City not found. Skipping...
# Processing Record 8 of Set 4 | bereda
# Processing Record 9 of Set 4 | taoudenni
# Processing Record 10 of Set 4 | beloha
# Processing Record 11 of Set 4 | hobart
# Processing Record 12 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 4 | velsk
# Processing Record 14 of Set 4 | gaya
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | ust-kuyga
# Processing Record 17 of Set 4 | kolosovka
# Processing Record 18 of Set 4 | zarand
# Processing Record 19 of Set 4 | inyonga
# Processing Record 20 of Set 4 | havoysund
# Processing Record 21 of Set 4 | pevek
# Processing Record 22 of Set 4 | kapaa
# Processing Record 23 of Set 4 | hovd
# Processing Record 24 of Set 4 | souillac
# Processing Record 25 of Set 4 | colonia
# Processing Record 26 of Set 4 | vaitape
# Processing Record 27 of Set 4 | praia da vitoria
# Processing Record 28 of Set 4 | hobyo
# Processing Record 29 of Set 4 | havre-saint-pierre
# Processing Record 30 of Set 4 | nizwa
# Processing Record 31 of Set 4 | voyvozh
# Processing Record 32 of Set 4 | san patricio
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | mezen
# Processing Record 35 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 36 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 4 | haines junction
# Processing Record 38 of Set 4 | victoria
# Processing Record 39 of Set 4 | avanigadda
# Processing Record 40 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 4 | rio claro
# Processing Record 42 of Set 4 | namibe
# Processing Record 43 of Set 4 | tasiilaq
# Processing Record 44 of Set 4 | cabedelo
# Processing Record 45 of Set 4 | sainte-maxime
# Processing Record 46 of Set 4 | marfino
# Processing Record 47 of Set 4 | georgetown
# Processing Record 48 of Set 4 | sochi
# Processing Record 49 of Set 4 | chapais
# Processing Record 50 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 5 | bakal
# Processing Record 2 of Set 5 | isangel
# Processing Record 3 of Set 5 | bongandanga
# Processing Record 4 of Set 5 | jose bonifacio
# Processing Record 5 of Set 5 | dickinson
# Processing Record 6 of Set 5 | sao filipe
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | santo domingo
# Processing Record 9 of Set 5 | alofi
# Processing Record 10 of Set 5 | ust-nera
# Processing Record 11 of Set 5 | ilulissat
# Processing Record 12 of Set 5 | kisangani
# Processing Record 13 of Set 5 | ginir
# Processing Record 14 of Set 5 | griffith
# Processing Record 15 of Set 5 | nouakchott
# Processing Record 16 of Set 5 | erenhot
# Processing Record 17 of Set 5 | may pen
# Processing Record 18 of Set 5 | kabare
# Processing Record 19 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 5 | neryungri
# Processing Record 21 of Set 5 | stankov
# Processing Record 22 of Set 5 | ucluelet
# Processing Record 23 of Set 5 | bundaberg
# Processing Record 24 of Set 5 | kruisfontein
# Processing Record 25 of Set 5 | songjianghe
# Processing Record 26 of Set 5 | karratha
# Processing Record 27 of Set 5 | torbay
# Processing Record 28 of Set 5 | qandala
# Processing Record 29 of Set 5 | mar del plata
# Processing Record 30 of Set 5 | ketchikan
# Processing Record 31 of Set 5 | bolokhovo
# Processing Record 32 of Set 5 | dunedin
# Processing Record 33 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 5 | hay river
# Processing Record 35 of Set 5 | roxas
# Processing Record 36 of Set 5 | ejido
# Processing Record 37 of Set 5 | uvinza
# Processing Record 38 of Set 5 | bengkulu
# Processing Record 39 of Set 5 | sazonovo
# Processing Record 40 of Set 5 | barabai
# Processing Record 41 of Set 5 | mantua
# Processing Record 42 of Set 5 | svetlaya
# Processing Record 43 of Set 5 | ahipara
# Processing Record 44 of Set 5 | faanui
# Processing Record 45 of Set 5 | erdenet
# Processing Record 46 of Set 5 | svetlogorsk
# Processing Record 47 of Set 5 | bima
# Processing Record 48 of Set 5 | kodiak
# Processing Record 49 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 5 | domoni
# Processing Record 1 of Set 6 | feodosiya
# Processing Record 2 of Set 6 | kaitangata
# Processing Record 3 of Set 6 | itarema
# Processing Record 4 of Set 6 | da nang
# Processing Record 5 of Set 6 | meulaboh
# Processing Record 6 of Set 6 | los llanos de aridane
# Processing Record 7 of Set 6 | luwuk
# Processing Record 8 of Set 6 | bialystok
# Processing Record 9 of Set 6 | moyale
# Processing Record 10 of Set 6 | talnakh
# Processing Record 11 of Set 6 | coahuayana
# Processing Record 12 of Set 6 | lucea
# Processing Record 13 of Set 6 | gushikawa
# Processing Record 14 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 15 of Set 6 | rabo de peixe
# Processing Record 16 of Set 6 | kungurtug
# Processing Record 17 of Set 6 | wichita
# Processing Record 18 of Set 6 | sayyan
# Processing Record 19 of Set 6 | porto novo
# Processing Record 20 of Set 6 | todos santos
# Processing Record 21 of Set 6 | prabumulih
# Processing Record 22 of Set 6 | yarmouth
# Processing Record 23 of Set 6 | codrington
# Processing Record 24 of Set 6 | khasan
# Processing Record 25 of Set 6 | malakal
# Processing Record 26 of Set 6 | lagunas
# Processing Record 27 of Set 6 | merauke
# Processing Record 28 of Set 6 | caravelas
# Processing Record 29 of Set 6 | nome
# Processing Record 30 of Set 6 | verkhoyansk
# Processing Record 31 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 32 of Set 6 | nanortalik
# Processing Record 33 of Set 6 | la ronge
# Processing Record 34 of Set 6 | camana
# Processing Record 35 of Set 6 | yar-sale
# Processing Record 36 of Set 6 | sumbawanga
# Processing Record 37 of Set 6 | farafenni
# Processing Record 38 of Set 6 | arcata
# Processing Record 39 of Set 6 | bethel
# Processing Record 40 of Set 6 | tarnogskiy gorodok
# Processing Record 41 of Set 6 | kaveripattinam
# Processing Record 42 of Set 6 | hofn
# Processing Record 43 of Set 6 | adrar
# Processing Record 44 of Set 6 | bodden town
# Processing Record 45 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 6 | hot springs
# Processing Record 47 of Set 6 | sfantu gheorghe
# Processing Record 48 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 6 | sibolga
# Processing Record 50 of Set 6 | kieta
# Processing Record 1 of Set 7 | lixourion
# Processing Record 2 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 3 of Set 7 | kununurra
# Processing Record 4 of Set 7 | amapa
# Processing Record 5 of Set 7 | takaka
# Processing Record 6 of Set 7 | brigantine
# Processing Record 7 of Set 7 | rincon
# Processing Record 8 of Set 7 | mahibadhoo
# Processing Record 9 of Set 7 | ippy
# Processing Record 10 of Set 7 | eskisehir
# Processing Record 11 of Set 7 | jinka
# Processing Record 12 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 13 of Set 7 | te anau
# Processing Record 14 of Set 7 | keti bandar
# Processing Record 15 of Set 7 | revda
# Processing Record 16 of Set 7 | clyde river
# Processing Record 17 of Set 7 | salalah
# Processing Record 18 of Set 7 | pitanga
# Processing Record 19 of Set 7 | tabialan
# City not found. Skipping...
# Processing Record 20 of Set 7 | eyrarbakki
# Processing Record 21 of Set 7 | lazi
# Processing Record 22 of Set 7 | aksu
# Processing Record 23 of Set 7 | saint-joseph
# Processing Record 24 of Set 7 | myskhako
# Processing Record 25 of Set 7 | qarqin
# Processing Record 26 of Set 7 | esso
# Processing Record 27 of Set 7 | toguchin
# Processing Record 28 of Set 7 | villa maria
# Processing Record 29 of Set 7 | sangar
# Processing Record 30 of Set 7 | puerto escondido
# Processing Record 31 of Set 7 | samarai
# Processing Record 32 of Set 7 | hurghada
# Processing Record 33 of Set 7 | auki
# Processing Record 34 of Set 7 | raga
# Processing Record 35 of Set 7 | bac lieu
# Processing Record 36 of Set 7 | lakes entrance
# Processing Record 37 of Set 7 | kerki
# City not found. Skipping...
# Processing Record 38 of Set 7 | oskarshamn
# Processing Record 39 of Set 7 | asyut
# Processing Record 40 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 41 of Set 7 | piqua
# Processing Record 42 of Set 7 | port lincoln
# Processing Record 43 of Set 7 | bambanglipuro
# Processing Record 44 of Set 7 | suntar
# Processing Record 45 of Set 7 | axim
# Processing Record 46 of Set 7 | cidreira
# Processing Record 47 of Set 7 | oliveira dos brejinhos
# Processing Record 48 of Set 7 | baker city
# Processing Record 49 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 7 | hervey bay
# Processing Record 1 of Set 8 | lazaro cardenas
# Processing Record 2 of Set 8 | pangnirtung
# Processing Record 3 of Set 8 | mayo
# Processing Record 4 of Set 8 | boyolangu
# Processing Record 5 of Set 8 | manacapuru
# Processing Record 6 of Set 8 | vysokogornyy
# Processing Record 7 of Set 8 | pokrovsk
# Processing Record 8 of Set 8 | tacuarembo
# Processing Record 9 of Set 8 | exmouth
# Processing Record 10 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 8 | triolet
# Processing Record 12 of Set 8 | goma
# Processing Record 13 of Set 8 | mwanza
# Processing Record 14 of Set 8 | coquimbo
# Processing Record 15 of Set 8 | piedras negras
# Processing Record 16 of Set 8 | aksarka
# Processing Record 17 of Set 8 | show low
# Processing Record 18 of Set 8 | ndioum
# Processing Record 19 of Set 8 | general roca
# Processing Record 20 of Set 8 | osypenko
# Processing Record 21 of Set 8 | porto torres
# Processing Record 22 of Set 8 | airai
# Processing Record 23 of Set 8 | dingle
# Processing Record 24 of Set 8 | novoilinsk
# Processing Record 25 of Set 8 | lagoa
# Processing Record 26 of Set 8 | vardo
# Processing Record 27 of Set 8 | kurilsk
# Processing Record 28 of Set 8 | siva
# Processing Record 29 of Set 8 | east london
# Processing Record 30 of Set 8 | okha
# Processing Record 31 of Set 8 | quixeramobim
# Processing Record 32 of Set 8 | meadow lake
# Processing Record 33 of Set 8 | avera
# Processing Record 34 of Set 8 | portland
# Processing Record 35 of Set 8 | gizo
# Processing Record 36 of Set 8 | takoradi
# Processing Record 37 of Set 8 | tuatapere
# Processing Record 38 of Set 8 | haapu
# City not found. Skipping...
# Processing Record 39 of Set 8 | bermejo
# Processing Record 40 of Set 8 | razdolinsk
# Processing Record 41 of Set 8 | labrea
# Processing Record 42 of Set 8 | bouillante
# Processing Record 43 of Set 8 | nemuro
# Processing Record 44 of Set 8 | kalach-na-donu
# Processing Record 45 of Set 8 | santa isabel do rio negro
# Processing Record 46 of Set 8 | villa carlos paz
# Processing Record 47 of Set 8 | saint george
# Processing Record 48 of Set 8 | elwood
# Processing Record 49 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 8 | cariati
# Processing Record 1 of Set 9 | koulikoro
# Processing Record 2 of Set 9 | saldanha
# Processing Record 3 of Set 9 | katobu
# Processing Record 4 of Set 9 | nenjiang
# Processing Record 5 of Set 9 | layou
# Processing Record 6 of Set 9 | kimbe
# Processing Record 7 of Set 9 | viseu
# Processing Record 8 of Set 9 | yerbogachen
# Processing Record 9 of Set 9 | mabaruma
# Processing Record 10 of Set 9 | yulara
# Processing Record 11 of Set 9 | imeni babushkina
# Processing Record 12 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 9 | muriwai beach
# Processing Record 14 of Set 9 | pendleton
# Processing Record 15 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 9 | mareeba
# Processing Record 17 of Set 9 | port keats
# Processing Record 18 of Set 9 | poum
# Processing Record 19 of Set 9 | guozhen
# Processing Record 20 of Set 9 | shimoda
# Processing Record 21 of Set 9 | san cristobal
# Processing Record 22 of Set 9 | skegness
# Processing Record 23 of Set 9 | ahuimanu
# Processing Record 24 of Set 9 | ternate
# Processing Record 25 of Set 9 | liusha
# Processing Record 26 of Set 9 | arlit
# Processing Record 27 of Set 9 | borba
# Processing Record 28 of Set 9 | samana
# Processing Record 29 of Set 9 | high prairie
# Processing Record 30 of Set 9 | innisfail
# Processing Record 31 of Set 9 | emba
# Processing Record 32 of Set 9 | bondoukou
# Processing Record 33 of Set 9 | baykit
# Processing Record 34 of Set 9 | malkangiri
# Processing Record 35 of Set 9 | harper
# Processing Record 36 of Set 9 | lasa
# Processing Record 37 of Set 9 | hamadan
# Processing Record 38 of Set 9 | joensuu
# Processing Record 39 of Set 9 | youghal
# Processing Record 40 of Set 9 | picota
# Processing Record 41 of Set 9 | obihiro
# Processing Record 42 of Set 9 | polyarnyy
# Processing Record 43 of Set 9 | egersund
# Processing Record 44 of Set 9 | ati
# Processing Record 45 of Set 9 | alexandria
# Processing Record 46 of Set 9 | leningradskiy
# Processing Record 47 of Set 9 | pedernales
# Processing Record 48 of Set 9 | bonfim
# Processing Record 49 of Set 9 | klaksvik
# Processing Record 50 of Set 9 | burica
# City not found. Skipping...
# Processing Record 1 of Set 10 | oktyabrskiy
# Processing Record 2 of Set 10 | ebetsu
# Processing Record 3 of Set 10 | altena
# Processing Record 4 of Set 10 | vacaria
# Processing Record 5 of Set 10 | rundu
# Processing Record 6 of Set 10 | buala
# Processing Record 7 of Set 10 | kolga
# Processing Record 8 of Set 10 | narsaq
# Processing Record 9 of Set 10 | abay
# Processing Record 10 of Set 10 | wajima
# Processing Record 11 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 10 | christchurch
# Processing Record 13 of Set 10 | chodziez
# Processing Record 14 of Set 10 | cukai
# Processing Record 15 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 16 of Set 10 | roman
# Processing Record 17 of Set 10 | cherskiy
# Processing Record 18 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 19 of Set 10 | sur
# Processing Record 20 of Set 10 | ekhabi
# Processing Record 21 of Set 10 | kilrush
# Processing Record 22 of Set 10 | hualmay
# Processing Record 23 of Set 10 | aras
# Processing Record 24 of Set 10 | clifton springs
# Processing Record 25 of Set 10 | beringovskiy
# Processing Record 26 of Set 10 | shetpe
# Processing Record 27 of Set 10 | capaci
# Processing Record 28 of Set 10 | jutai
# Processing Record 29 of Set 10 | carlsbad
# Processing Record 30 of Set 10 | vestmannaeyjar
# Processing Record 31 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 10 | veseloyarsk
# Processing Record 33 of Set 10 | inuvik
# Processing Record 34 of Set 10 | poddorye
# Processing Record 35 of Set 10 | dahanu
# Processing Record 36 of Set 10 | bagli
# Processing Record 37 of Set 10 | shimanovsk
# Processing Record 38 of Set 10 | coxim
# Processing Record 39 of Set 10 | varkaus
# Processing Record 40 of Set 10 | lianzhou
# Processing Record 41 of Set 10 | hamilton
# Processing Record 42 of Set 10 | riyadh
# Processing Record 43 of Set 10 | rongcheng
# Processing Record 44 of Set 10 | vila velha
# Processing Record 45 of Set 10 | saint-pierre
# Processing Record 46 of Set 10 | soe
# Processing Record 47 of Set 10 | college
# Processing Record 48 of Set 10 | virden
# Processing Record 49 of Set 10 | rabak
# Processing Record 50 of Set 10 | palmer
# Processing Record 1 of Set 11 | san vicente
# Processing Record 2 of Set 11 | westpunt
# City not found. Skipping...
# Processing Record 3 of Set 11 | riaba
# City not found. Skipping...
# Processing Record 4 of Set 11 | mpika
# Processing Record 5 of Set 11 | basco
# Processing Record 6 of Set 11 | wahiawa
# Processing Record 7 of Set 11 | tete
# Processing Record 8 of Set 11 | sabang
# Processing Record 9 of Set 11 | valley
# Processing Record 10 of Set 11 | dubrovka
# Processing Record 11 of Set 11 | komsomolskiy
# Processing Record 12 of Set 11 | chake chake
# Processing Record 13 of Set 11 | harnosand
# Processing Record 14 of Set 11 | pokrovskoye
# Processing Record 15 of Set 11 | olafsvik
# Processing Record 16 of Set 11 | funadhoo
# Processing Record 17 of Set 11 | gazni
# City not found. Skipping...
# Processing Record 18 of Set 11 | dawan
# Processing Record 19 of Set 11 | gorom-gorom
# Processing Record 20 of Set 11 | znamenka
# Processing Record 21 of Set 11 | maniitsoq
# Processing Record 22 of Set 11 | minot
# Processing Record 23 of Set 11 | sogdiondon
# City not found. Skipping...
# Processing Record 24 of Set 11 | placido de castro
# Processing Record 25 of Set 11 | chunskiy
# Processing Record 26 of Set 11 | copala
# Processing Record 27 of Set 11 | dapaong
# Processing Record 28 of Set 11 | anloga
# Processing Record 29 of Set 11 | mbandaka
# Processing Record 30 of Set 11 | lata
# Processing Record 31 of Set 11 | evensk
# Processing Record 32 of Set 11 | santa maria
# Processing Record 33 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 34 of Set 11 | kyren
# Processing Record 35 of Set 11 | ahar
# Processing Record 36 of Set 11 | port macquarie
# Processing Record 37 of Set 11 | horsham
# Processing Record 38 of Set 11 | solnechnyy
# Processing Record 39 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 11 | salina cruz
# Processing Record 41 of Set 11 | kuito
# Processing Record 42 of Set 11 | villeta
# Processing Record 43 of Set 11 | nouadhibou
# Processing Record 44 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 45 of Set 11 | karlshamn
# Processing Record 46 of Set 11 | chumphon
# Processing Record 47 of Set 11 | acarau
# Processing Record 48 of Set 11 | krasnopillya
# Processing Record 49 of Set 11 | zyryanka
# Processing Record 50 of Set 11 | lantawan
# Processing Record 1 of Set 12 | vanimo
# Processing Record 2 of Set 12 | segalstad
# City not found. Skipping...
# Processing Record 3 of Set 12 | visakhapatnam
# Processing Record 4 of Set 12 | bemidji
# Processing Record 5 of Set 12 | macomb
# Processing Record 6 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 12 | moshupa
# Processing Record 8 of Set 12 | cacapava
# Processing Record 9 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 10 of Set 12 | sandnessjoen
# Processing Record 11 of Set 12 | koyilandi
# City not found. Skipping...
# Processing Record 12 of Set 12 | burnham
# Processing Record 13 of Set 12 | thinadhoo
# Processing Record 14 of Set 12 | cape coast
# Processing Record 15 of Set 12 | nova praha
# Processing Record 16 of Set 12 | aborlan
# Processing Record 17 of Set 12 | toora-khem
# Processing Record 18 of Set 12 | estevan
# Processing Record 19 of Set 12 | ambon
# Processing Record 20 of Set 12 | salym
# Processing Record 21 of Set 12 | edd
# Processing Record 22 of Set 12 | lufilufi
# Processing Record 23 of Set 12 | madera
# Processing Record 24 of Set 12 | marsh harbour
# Processing Record 25 of Set 12 | mayumba
# Processing Record 26 of Set 12 | jiazi
# Processing Record 27 of Set 12 | mogadishu
# Processing Record 28 of Set 12 | tiznit
# Processing Record 29 of Set 12 | ilek
# Processing Record 30 of Set 12 | katsuura
# Processing Record 31 of Set 12 | loei
# Processing Record 32 of Set 12 | mehamn
# Processing Record 33 of Set 12 | winton
# Processing Record 34 of Set 12 | tabuk
# Processing Record 35 of Set 12 | gananoque
# Processing Record 36 of Set 12 | pandrup
# Processing Record 37 of Set 12 | pacific grove
# Processing Record 38 of Set 12 | polunochnoye
# Processing Record 39 of Set 12 | buluang
# Processing Record 40 of Set 12 | gamba
# Processing Record 41 of Set 12 | balkanabat
# Processing Record 42 of Set 12 | sao domingos
# Processing Record 43 of Set 12 | pedro juan caballero
# Processing Record 44 of Set 12 | san antonio
# Processing Record 45 of Set 12 | mazagao
# Processing Record 46 of Set 12 | linjiang
# Processing Record 47 of Set 12 | yenagoa
# Processing Record 48 of Set 12 | quzhou
# Processing Record 49 of Set 12 | upernavik
# Processing Record 50 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 1 of Set 13 | katima mulilo
# Processing Record 2 of Set 13 | agadir
# Processing Record 3 of Set 13 | abakaliki
# Processing Record 4 of Set 13 | waddan
# Processing Record 5 of Set 13 | lago da pedra
# Processing Record 6 of Set 13 | red deer
# Processing Record 7 of Set 13 | arman
# Processing Record 8 of Set 13 | kloulklubed
# Processing Record 9 of Set 13 | chalus
# Processing Record 10 of Set 13 | laguna
# Processing Record 11 of Set 13 | taltal
# Processing Record 12 of Set 13 | kamenka
# Processing Record 13 of Set 13 | ulladulla
# Processing Record 14 of Set 13 | bontang
# Processing Record 15 of Set 13 | mackay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# # Create a DataFrame of City Weather Data

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Siverek  37.7550   39.3167     29.01        76           0        6.06
# 1     Aklavik  68.2191 -135.0107    -17.57        93         100        2.53
# 2      Oswego  43.4501  -76.1497     28.90        57         100        1.99
# 3       Vaini -21.2000 -175.2000     82.96        77          21       14.14
# 4   Busselton -33.6500  115.3333     73.04        35           0        8.66
# 5        Hilo  19.7297 -155.0900     80.33        69         100       13.80
# 6     Ushuaia -54.8000  -68.3000     49.66        81          75        5.75
# 7  Nikolskoye  59.7035   30.7861     30.87        96         100        8.10
# 8     Husavik  66.0449  -17.3389     35.51        78         100       14.56
# 9     Kulunda  52.5660   78.9385     -5.93        98          19        6.69
#
#   Country                 Date
# 0      TR  2022-01-28 01:40:25
# 1      CA  2022-01-28 01:40:26
# 2      US  2022-01-28 01:40:26
# 3      TO  2022-01-28 01:40:26
# 4      AU  2022-01-28 01:40:27
# 5      US  2022-01-28 01:40:27
# 6      AR  2022-01-28 01:40:27
# 7      RU  2022-01-28 01:40:28
# 8      IS  2022-01-28 01:38:38
# 9      RU  2022-01-28 01:40:28

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0     Siverek      TR  2022-01-28 01:40:25  37.7550   39.3167     29.01
# 1     Aklavik      CA  2022-01-28 01:40:26  68.2191 -135.0107    -17.57
# 2      Oswego      US  2022-01-28 01:40:26  43.4501  -76.1497     28.90
# 3       Vaini      TO  2022-01-28 01:40:26 -21.2000 -175.2000     82.96
# 4   Busselton      AU  2022-01-28 01:40:27 -33.6500  115.3333     73.04
# 5        Hilo      US  2022-01-28 01:40:27  19.7297 -155.0900     80.33
# 6     Ushuaia      AR  2022-01-28 01:40:27 -54.8000  -68.3000     49.66
# 7  Nikolskoye      RU  2022-01-28 01:40:28  59.7035   30.7861     30.87
# 8     Husavik      IS  2022-01-28 01:38:38  66.0449  -17.3389     35.51
# 9     Kulunda      RU  2022-01-28 01:40:28  52.5660   78.9385     -5.93
#
#    Humidity  Cloudiness  Wind Speed
# 0        76           0        6.06
# 1        93         100        2.53
# 2        57         100        1.99
# 3        77          21       14.14
# 4        35           0        8.66
# 5        69         100       13.80
# 6        81          75        5.75
# 7        96         100        8.10
# 8        78         100       14.56
# 9        98          19        6.69

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")

# %% [markdown]
# # Plot Latitude vs. Temperature

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats, max_temps,
            edgecolor = "black",
            linewidths = 1,
            marker = "o",
            alpha = 0.8,
            label = "Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %% [markdown]
# # Plot Latitude vs. Humidity

# %%
# Build the scatter plot for latitude vs. humidity.
plt.scatter(lats, humidity,
            edgecolor = "black",
            linewidths = 1,
            marker = "o",
            alpha = 0.8,
            label = "Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %% [markdown]
# # Plot Latitude vs. Cloudiness

# %%
# Build the scatter plot for latitude vs. cloudiness.
plt.scatter(lats, cloudiness,
            edgecolor = "black",
            linewidths = 1,
            marker = "o",
            alpha = 0.8,
            label = "Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%)"+ time.strftime("%x"))
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %% [markdown]
# #  Plot Latitude vs. Wind Speed

# %%
# Build the scatter plot for latitude vs. wind speed.
plt.scatter(lats, wind_speed,
            edgecolor = "black",
            linewidths = 1,
            marker = "o",
            alpha = 0.8,
            label = "Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %% [markdown]
# # Find the Correlation Between Latitude and Maximum Temperature

# %% [markdown]
# Create a Linear Regression Function

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to perform linear regression on the weather data 
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope, 2)) + "x " + str(round(intercept, 2))
    
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize = 15, color = "red")
    plt.title(title)
    plt.xlabel("Latitude")
    plt.ylabel(y_label)
    plt.show()

# %% [markdown]
# Create the Hemisphere DataFrames

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                 Punta Arenas
# Country                        CL
# Date          2022-01-28 01:40:29
# Lat                        -53.15
# Lng                      -70.9167
# Max Temp                    50.11
# Humidity                       87
# Cloudiness                      0
# Wind Speed                   9.22
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 555    False
# 556     True
# 557    False
# 558     True
# 559    False
# Name: Lat, Length: 560, dtype: bool

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %% [markdown]
# Perform Linear Regression on the Maximum Temperature for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Northern Hemisphere \n for Maximum Temperature",
                      "Max Temp", (0,0))

# %% [markdown]
# Perform Linear Regression on the Maximum Temperature for the Northern Hemisphere

# %%
# Linear regression on the Northern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Southern Hemisphere \n for Maximum Temperature",
                      "Max Temp", (-50,90))

# %% [markdown]
# # Find the Correlation Between Latitude and Percent Humidity

# %%
# Linear regression on the Norhern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Northern Hemisphere \n for % Humidity",
                      "% Humidity", (40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Southern Hemisphere \n for % Humidity",
                      "% Humidity", (-50,15))

# %% [markdown]
# # Find the Correlation Between Latitude and Percent Cloudiness

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Northern Hemisphere \n for % Cloudiness",
                      "% Cloudiness", (0,55))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Southern Hemisphere \n for % Cloudiness",
                      "% Cloudiness", (-55,50))

# %% [markdown]
# # Find the Correlation Between Latitude and Wind Speed

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Northern Hemisphere \n for Wind Speed",
                      "Wind Speed (mph)", (0,30))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Southern Hemisphere \n for Wind Speed",
                      "Wind Speed (mph)", (-50,25))
