# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 1500)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 1500)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# **Get the nearest city using the citipy module.**

# %%
# Import citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 605

# %% [markdown]
# **Perform an API call with the OpenWeatherMap and Retrieve the following information from the API call:**
#
# **Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky).**

# %%
import requests
from config import challenge_weather_api_key
import time
from datetime import datetime

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + challenge_weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Create counter.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60) # Pause for 60 seconds.
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | iqaluit
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | saint-augustin
# Processing Record 7 of Set 1 | marsh harbour
# Processing Record 8 of Set 1 | tiarei
# Processing Record 9 of Set 1 | tukrah
# Processing Record 10 of Set 1 | kenora
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | victoria
# Processing Record 13 of Set 1 | tocopilla
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 1 | brae
# Processing Record 17 of Set 1 | charters towers
# Processing Record 18 of Set 1 | berlevag
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | bandarbeyla
# Processing Record 21 of Set 1 | namatanai
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | klaksvik
# Processing Record 24 of Set 1 | qandala
# Processing Record 25 of Set 1 | aklavik
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | babu
# Processing Record 28 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 1 | tuatapere
# Processing Record 30 of Set 1 | vanavara
# Processing Record 31 of Set 1 | mana
# Processing Record 32 of Set 1 | nishihara
# Processing Record 33 of Set 1 | hasaki
# Processing Record 34 of Set 1 | kavieng
# Processing Record 35 of Set 1 | coihaique
# Processing Record 36 of Set 1 | saint anthony
# Processing Record 37 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 1 | bilibino
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | cabo san lucas
# Processing Record 41 of Set 1 | chadiza
# Processing Record 42 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 1 | leningradskiy
# Processing Record 44 of Set 1 | provideniya
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | kupang
# Processing Record 47 of Set 1 | cabimas
# Processing Record 48 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 1 | punta arenas
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | codrington
# Processing Record 2 of Set 2 | paamiut
# Processing Record 3 of Set 2 | baykit
# Processing Record 4 of Set 2 | padang
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | ushuaia
# Processing Record 7 of Set 2 | portovelo
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | hailun
# Processing Record 10 of Set 2 | lagoa
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | kahului
# Processing Record 15 of Set 2 | lom sak
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | chokurdakh
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | lampa
# Processing Record 20 of Set 2 | praya
# Processing Record 21 of Set 2 | inderborskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | ardmore
# Processing Record 23 of Set 2 | canutama
# Processing Record 24 of Set 2 | jamestown
# Processing Record 25 of Set 2 | zyryanka
# Processing Record 26 of Set 2 | flinders
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | tombouctou
# Processing Record 29 of Set 2 | karatuzskoye
# Processing Record 30 of Set 2 | meulaboh
# Processing Record 31 of Set 2 | khandbari
# Processing Record 32 of Set 2 | sawakin
# Processing Record 33 of Set 2 | hilo
# Processing Record 34 of Set 2 | faanui
# Processing Record 35 of Set 2 | north bend
# Processing Record 36 of Set 2 | ascension
# Processing Record 37 of Set 2 | shimoda
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | gazanjyk
# Processing Record 40 of Set 2 | cape town
# Processing Record 41 of Set 2 | sur
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | bulgan
# Processing Record 44 of Set 2 | marawi
# Processing Record 45 of Set 2 | riacho de santana
# Processing Record 46 of Set 2 | buritis
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | sao filipe
# Processing Record 49 of Set 2 | kungurtug
# Processing Record 50 of Set 2 | geraldton
# Processing Record 1 of Set 3 | seoul
# Processing Record 2 of Set 3 | kruisfontein
# Processing Record 3 of Set 3 | kasongo-lunda
# Processing Record 4 of Set 3 | morant bay
# Processing Record 5 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 3 | ritchie
# Processing Record 7 of Set 3 | poli
# Processing Record 8 of Set 3 | mahebourg
# Processing Record 9 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 3 | honningsvag
# Processing Record 11 of Set 3 | portland
# Processing Record 12 of Set 3 | tambacounda
# Processing Record 13 of Set 3 | port augusta
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | vaini
# Processing Record 16 of Set 3 | ballina
# Processing Record 17 of Set 3 | port hardy
# Processing Record 18 of Set 3 | balsas
# Processing Record 19 of Set 3 | yichun
# Processing Record 20 of Set 3 | boguchany
# Processing Record 21 of Set 3 | barreirinhas
# Processing Record 22 of Set 3 | kota kinabalu
# Processing Record 23 of Set 3 | barrow
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | matagami
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | acapulco
# Processing Record 28 of Set 3 | alenquer
# Processing Record 29 of Set 3 | vavuniya
# Processing Record 30 of Set 3 | sindor
# Processing Record 31 of Set 3 | arraial do cabo
# Processing Record 32 of Set 3 | salalah
# Processing Record 33 of Set 3 | paciran
# Processing Record 34 of Set 3 | mezen
# Processing Record 35 of Set 3 | san patricio
# Processing Record 36 of Set 3 | asau
# Processing Record 37 of Set 3 | omboue
# Processing Record 38 of Set 3 | dingle
# Processing Record 39 of Set 3 | luwuk
# Processing Record 40 of Set 3 | beloha
# Processing Record 41 of Set 3 | longyearbyen
# Processing Record 42 of Set 3 | bodden town
# Processing Record 43 of Set 3 | biak
# Processing Record 44 of Set 3 | port keats
# Processing Record 45 of Set 3 | alice springs
# Processing Record 46 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 3 | coquimbo
# Processing Record 48 of Set 3 | vardo
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | stepnogorsk
# Processing Record 1 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 4 | sobolevo
# Processing Record 3 of Set 4 | buala
# Processing Record 4 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 4 | sabha
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | mar del plata
# Processing Record 8 of Set 4 | sokoni
# Processing Record 9 of Set 4 | walvis bay
# Processing Record 10 of Set 4 | fairbanks
# Processing Record 11 of Set 4 | jingdezhen
# Processing Record 12 of Set 4 | toamasina
# Processing Record 13 of Set 4 | atuona
# Processing Record 14 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 4 | fort nelson
# Processing Record 16 of Set 4 | busselton
# Processing Record 17 of Set 4 | zaraza
# Processing Record 18 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 4 | castro
# Processing Record 20 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 4 | ancud
# Processing Record 22 of Set 4 | omsukchan
# Processing Record 23 of Set 4 | chuy
# Processing Record 24 of Set 4 | ville-marie
# Processing Record 25 of Set 4 | qaanaaq
# Processing Record 26 of Set 4 | netivot
# Processing Record 27 of Set 4 | mecca
# Processing Record 28 of Set 4 | vite
# Processing Record 29 of Set 4 | east london
# Processing Record 30 of Set 4 | winnemucca
# Processing Record 31 of Set 4 | tiksi
# Processing Record 32 of Set 4 | necochea
# Processing Record 33 of Set 4 | calabozo
# Processing Record 34 of Set 4 | cherskiy
# Processing Record 35 of Set 4 | kazan
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | the pas
# Processing Record 38 of Set 4 | esperance
# Processing Record 39 of Set 4 | koroni
# Processing Record 40 of Set 4 | yellowknife
# Processing Record 41 of Set 4 | mount gambier
# Processing Record 42 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 4 | svetlogorsk
# Processing Record 44 of Set 4 | saint-pierre
# Processing Record 45 of Set 4 | sayat
# Processing Record 46 of Set 4 | tres arroyos
# Processing Record 47 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 4 | karratha
# Processing Record 49 of Set 4 | sfantu gheorghe
# Processing Record 50 of Set 4 | honiara
# Processing Record 1 of Set 5 | torbay
# Processing Record 2 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 5 | mehamn
# Processing Record 4 of Set 5 | sarany
# Processing Record 5 of Set 5 | port elizabeth
# Processing Record 6 of Set 5 | bengkulu
# Processing Record 7 of Set 5 | college
# Processing Record 8 of Set 5 | margate
# Processing Record 9 of Set 5 | celestun
# Processing Record 10 of Set 5 | northam
# Processing Record 11 of Set 5 | ribeira grande
# Processing Record 12 of Set 5 | burnie
# Processing Record 13 of Set 5 | camacha
# Processing Record 14 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 5 | vila velha
# Processing Record 16 of Set 5 | qaqortoq
# Processing Record 17 of Set 5 | alugan
# Processing Record 18 of Set 5 | xiuyan
# Processing Record 19 of Set 5 | sibolga
# Processing Record 20 of Set 5 | nantucket
# Processing Record 21 of Set 5 | sao pedro do sul
# Processing Record 22 of Set 5 | klos
# Processing Record 23 of Set 5 | utena
# Processing Record 24 of Set 5 | nakhon phanom
# Processing Record 25 of Set 5 | mus
# Processing Record 26 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 5 | tuktoyaktuk
# Processing Record 28 of Set 5 | airai
# Processing Record 29 of Set 5 | muros
# Processing Record 30 of Set 5 | darhan
# Processing Record 31 of Set 5 | narathiwat
# Processing Record 32 of Set 5 | banjar
# Processing Record 33 of Set 5 | myrtle beach
# Processing Record 34 of Set 5 | yeppoon
# Processing Record 35 of Set 5 | sumbe
# Processing Record 36 of Set 5 | nouadhibou
# Processing Record 37 of Set 5 | komsomolskiy
# Processing Record 38 of Set 5 | bathsheba
# Processing Record 39 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 5 | huilong
# Processing Record 41 of Set 5 | aswan
# Processing Record 42 of Set 5 | yar-sale
# Processing Record 43 of Set 5 | verkhnevilyuysk
# Processing Record 44 of Set 5 | porbandar
# Processing Record 45 of Set 5 | pangnirtung
# Processing Record 46 of Set 5 | colac
# Processing Record 47 of Set 5 | nome
# Processing Record 48 of Set 5 | polunochnoye
# Processing Record 49 of Set 5 | marshfield
# Processing Record 50 of Set 5 | richards bay
# Processing Record 1 of Set 6 | port hueneme
# Processing Record 2 of Set 6 | deputatskiy
# Processing Record 3 of Set 6 | sinnamary
# Processing Record 4 of Set 6 | pisco
# Processing Record 5 of Set 6 | half moon bay
# Processing Record 6 of Set 6 | santa barbara
# Processing Record 7 of Set 6 | boden
# Processing Record 8 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 6 | beira
# Processing Record 10 of Set 6 | kingsland
# Processing Record 11 of Set 6 | williston
# Processing Record 12 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 6 | mokhsogollokh
# Processing Record 14 of Set 6 | bambous virieux
# Processing Record 15 of Set 6 | avera
# Processing Record 16 of Set 6 | lorengau
# Processing Record 17 of Set 6 | faya
# Processing Record 18 of Set 6 | maningrida
# Processing Record 19 of Set 6 | ponta do sol
# Processing Record 20 of Set 6 | torquay
# Processing Record 21 of Set 6 | ostrovnoy
# Processing Record 22 of Set 6 | severo-kurilsk
# Processing Record 23 of Set 6 | fortuna
# Processing Record 24 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 26 of Set 6 | sitka
# Processing Record 27 of Set 6 | huarmey
# Processing Record 28 of Set 6 | kedrovyy
# Processing Record 29 of Set 6 | ilulissat
# Processing Record 30 of Set 6 | saint-philippe
# Processing Record 31 of Set 6 | piryion
# City not found. Skipping...
# Processing Record 32 of Set 6 | monteiro
# Processing Record 33 of Set 6 | mount isa
# Processing Record 34 of Set 6 | nabire
# Processing Record 35 of Set 6 | villa maria
# Processing Record 36 of Set 6 | kibaha
# Processing Record 37 of Set 6 | koslan
# Processing Record 38 of Set 6 | kavaratti
# Processing Record 39 of Set 6 | harlingen
# Processing Record 40 of Set 6 | dunedin
# Processing Record 41 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 42 of Set 6 | macamic
# Processing Record 43 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 6 | amapa
# Processing Record 45 of Set 6 | donegal
# Processing Record 46 of Set 6 | kondagaon
# Processing Record 47 of Set 6 | virginia beach
# Processing Record 48 of Set 6 | mackay
# Processing Record 49 of Set 6 | cabrobo
# Processing Record 50 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 2 of Set 7 | pevek
# Processing Record 3 of Set 7 | mareeba
# Processing Record 4 of Set 7 | birao
# Processing Record 5 of Set 7 | talas
# Processing Record 6 of Set 7 | nayoro
# Processing Record 7 of Set 7 | mahajanga
# Processing Record 8 of Set 7 | dolores
# Processing Record 9 of Set 7 | olinda
# Processing Record 10 of Set 7 | tokur
# Processing Record 11 of Set 7 | kudahuvadhoo
# Processing Record 12 of Set 7 | pedernales
# Processing Record 13 of Set 7 | yulara
# Processing Record 14 of Set 7 | maragogi
# Processing Record 15 of Set 7 | samarai
# Processing Record 16 of Set 7 | makokou
# Processing Record 17 of Set 7 | yarim
# Processing Record 18 of Set 7 | naruja
# Processing Record 19 of Set 7 | aksarka
# Processing Record 20 of Set 7 | alta floresta
# Processing Record 21 of Set 7 | tucuman
# Processing Record 22 of Set 7 | lasa
# Processing Record 23 of Set 7 | otse
# Processing Record 24 of Set 7 | saldanha
# Processing Record 25 of Set 7 | malartic
# Processing Record 26 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 7 | kisaran
# Processing Record 28 of Set 7 | bwanga
# Processing Record 29 of Set 7 | rawson
# Processing Record 30 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 7 | prince rupert
# Processing Record 32 of Set 7 | souillac
# Processing Record 33 of Set 7 | mangrol
# Processing Record 34 of Set 7 | port lincoln
# Processing Record 35 of Set 7 | lebu
# Processing Record 36 of Set 7 | cozumel
# Processing Record 37 of Set 7 | hirado
# Processing Record 38 of Set 7 | gunnedah
# Processing Record 39 of Set 7 | banepa
# Processing Record 40 of Set 7 | taoudenni
# Processing Record 41 of Set 7 | chumikan
# Processing Record 42 of Set 7 | norman wells
# Processing Record 43 of Set 7 | buraydah
# Processing Record 44 of Set 7 | olafsvik
# Processing Record 45 of Set 7 | jalu
# Processing Record 46 of Set 7 | leszno
# Processing Record 47 of Set 7 | murphy
# Processing Record 48 of Set 7 | saint-joseph
# Processing Record 49 of Set 7 | wonthaggi
# Processing Record 50 of Set 7 | ilam
# Processing Record 1 of Set 8 | vila praia de ancora
# Processing Record 2 of Set 8 | yerofey pavlovich
# Processing Record 3 of Set 8 | ahipara
# Processing Record 4 of Set 8 | goderich
# Processing Record 5 of Set 8 | skelleftea
# Processing Record 6 of Set 8 | sunyani
# Processing Record 7 of Set 8 | martaban
# Processing Record 8 of Set 8 | carnarvon
# Processing Record 9 of Set 8 | belmonte
# Processing Record 10 of Set 8 | mnogovershinnyy
# Processing Record 11 of Set 8 | troitsko-pechorsk
# Processing Record 12 of Set 8 | trinidad
# Processing Record 13 of Set 8 | canazas
# Processing Record 14 of Set 8 | lannion
# Processing Record 15 of Set 8 | lompoc
# Processing Record 16 of Set 8 | cartagena del chaira
# Processing Record 17 of Set 8 | sao joao da barra
# Processing Record 18 of Set 8 | plettenberg bay
# Processing Record 19 of Set 8 | warka
# Processing Record 20 of Set 8 | marzuq
# Processing Record 21 of Set 8 | mariinsk
# Processing Record 22 of Set 8 | okha
# Processing Record 23 of Set 8 | sayyan
# Processing Record 24 of Set 8 | hervey bay
# Processing Record 25 of Set 8 | polovinnoye
# Processing Record 26 of Set 8 | itarema
# Processing Record 27 of Set 8 | darnah
# Processing Record 28 of Set 8 | asosa
# Processing Record 29 of Set 8 | vilhena
# Processing Record 30 of Set 8 | gobabis
# Processing Record 31 of Set 8 | freeport
# Processing Record 32 of Set 8 | pacasmayo
# Processing Record 33 of Set 8 | los llanos de aridane
# Processing Record 34 of Set 8 | leh
# Processing Record 35 of Set 8 | gambela
# Processing Record 36 of Set 8 | gurupa
# Processing Record 37 of Set 8 | linxia
# Processing Record 38 of Set 8 | ray
# Processing Record 39 of Set 8 | ndele
# Processing Record 40 of Set 8 | havelock
# Processing Record 41 of Set 8 | pemex
# Processing Record 42 of Set 8 | kaitangata
# Processing Record 43 of Set 8 | staryy nadym
# Processing Record 44 of Set 8 | ongandjera
# Processing Record 45 of Set 8 | dwarka
# Processing Record 46 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 8 | cockburn town
# Processing Record 48 of Set 8 | tiznit
# Processing Record 49 of Set 8 | aromashevo
# Processing Record 50 of Set 8 | kieta
# Processing Record 1 of Set 9 | camaqua
# Processing Record 2 of Set 9 | yakeshi
# Processing Record 3 of Set 9 | rocha
# Processing Record 4 of Set 9 | hurricane
# Processing Record 5 of Set 9 | pahalgam
# Processing Record 6 of Set 9 | raudeberg
# Processing Record 7 of Set 9 | colesberg
# Processing Record 8 of Set 9 | vostok
# Processing Record 9 of Set 9 | guerrero negro
# Processing Record 10 of Set 9 | san ramon
# Processing Record 11 of Set 9 | nushki
# Processing Record 12 of Set 9 | kharp
# Processing Record 13 of Set 9 | alexandria
# Processing Record 14 of Set 9 | liverpool
# Processing Record 15 of Set 9 | terney
# Processing Record 16 of Set 9 | oussouye
# Processing Record 17 of Set 9 | maraa
# Processing Record 18 of Set 9 | campos
# Processing Record 19 of Set 9 | orcopampa
# Processing Record 20 of Set 9 | birchis
# Processing Record 21 of Set 9 | kulhudhuffushi
# Processing Record 22 of Set 9 | abu dhabi
# Processing Record 23 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 24 of Set 9 | xixiang
# Processing Record 25 of Set 9 | balkanabat
# Processing Record 26 of Set 9 | taunggyi
# Processing Record 27 of Set 9 | te anau
# Processing Record 28 of Set 9 | wlodawa
# Processing Record 29 of Set 9 | horta
# Processing Record 30 of Set 9 | elban
# Processing Record 31 of Set 9 | boende
# Processing Record 32 of Set 9 | santa isabel do rio negro
# Processing Record 33 of Set 9 | naze
# Processing Record 34 of Set 9 | menomonie
# Processing Record 35 of Set 9 | huambo
# Processing Record 36 of Set 9 | lindi
# Processing Record 37 of Set 9 | pacifica
# Processing Record 38 of Set 9 | basco
# Processing Record 39 of Set 9 | ardakan
# Processing Record 40 of Set 9 | tuy hoa
# Processing Record 41 of Set 9 | rio de janeiro
# Processing Record 42 of Set 9 | pakxan
# Processing Record 43 of Set 9 | isangel
# Processing Record 44 of Set 9 | naantali
# Processing Record 45 of Set 9 | nanortalik
# Processing Record 46 of Set 9 | alofi
# Processing Record 47 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 48 of Set 9 | boueni
# Processing Record 49 of Set 9 | roald
# Processing Record 50 of Set 9 | kindu
# Processing Record 1 of Set 10 | okhotsk
# Processing Record 2 of Set 10 | denpasar
# Processing Record 3 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 4 of Set 10 | yerbogachen
# Processing Record 5 of Set 10 | sembakung
# Processing Record 6 of Set 10 | katsuura
# Processing Record 7 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 8 of Set 10 | caravelas
# Processing Record 9 of Set 10 | barcelos
# Processing Record 10 of Set 10 | lyaskelya
# Processing Record 11 of Set 10 | saint george
# Processing Record 12 of Set 10 | port-cartier
# Processing Record 13 of Set 10 | dali
# Processing Record 14 of Set 10 | iranshahr
# Processing Record 15 of Set 10 | kultuk
# Processing Record 16 of Set 10 | kenai
# Processing Record 17 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 10 | macomer
# Processing Record 19 of Set 10 | deloraine
# Processing Record 20 of Set 10 | suntar
# Processing Record 21 of Set 10 | borogontsy
# Processing Record 22 of Set 10 | san ignacio
# Processing Record 23 of Set 10 | kabelvag
# Processing Record 24 of Set 10 | avola
# Processing Record 25 of Set 10 | westport
# Processing Record 26 of Set 10 | akashi
# Processing Record 27 of Set 10 | peniche
# Processing Record 28 of Set 10 | shizunai
# Processing Record 29 of Set 10 | borinskoye
# Processing Record 30 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 31 of Set 10 | puerto carreno
# Processing Record 32 of Set 10 | pacific grove
# Processing Record 33 of Set 10 | minab
# Processing Record 34 of Set 10 | brigantine
# Processing Record 35 of Set 10 | tarija
# Processing Record 36 of Set 10 | ixtapa
# Processing Record 37 of Set 10 | san-pedro
# Processing Record 38 of Set 10 | eureka
# Processing Record 39 of Set 10 | estrela
# Processing Record 40 of Set 10 | mandiana
# Processing Record 41 of Set 10 | nioro
# Processing Record 42 of Set 10 | kaeo
# Processing Record 43 of Set 10 | svetlyy
# Processing Record 44 of Set 10 | labuhan
# Processing Record 45 of Set 10 | kassala
# Processing Record 46 of Set 10 | darlowo
# Processing Record 47 of Set 10 | quatre cocos
# Processing Record 48 of Set 10 | sao felix do xingu
# Processing Record 49 of Set 10 | hailey
# Processing Record 50 of Set 10 | dakar
# Processing Record 1 of Set 11 | pandamatenga
# Processing Record 2 of Set 11 | san luis
# Processing Record 3 of Set 11 | bayji
# Processing Record 4 of Set 11 | nemuro
# Processing Record 5 of Set 11 | tanout
# Processing Record 6 of Set 11 | nhulunbuy
# Processing Record 7 of Set 11 | inhambane
# Processing Record 8 of Set 11 | shingu
# Processing Record 9 of Set 11 | kamalpur
# Processing Record 10 of Set 11 | villaviciosa
# Processing Record 11 of Set 11 | pontal do parana
# Processing Record 12 of Set 11 | koboldo
# City not found. Skipping...
# Processing Record 13 of Set 11 | chino valley
# Processing Record 14 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 15 of Set 11 | alekseyevsk
# Processing Record 16 of Set 11 | mto wa mbu
# Processing Record 17 of Set 11 | constitucion
# Processing Record 18 of Set 11 | luwingu
# Processing Record 19 of Set 11 | leland
# Processing Record 20 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 21 of Set 11 | tahta
# Processing Record 22 of Set 11 | cidreira
# Processing Record 23 of Set 11 | sakaraha
# Processing Record 24 of Set 11 | kefamenanu
# Processing Record 25 of Set 11 | zhangjiakou
# Processing Record 26 of Set 11 | madimba
# Processing Record 27 of Set 11 | tura
# Processing Record 28 of Set 11 | poum
# Processing Record 29 of Set 11 | malakal
# Processing Record 30 of Set 11 | shitanjing
# Processing Record 31 of Set 11 | rabo de peixe
# Processing Record 32 of Set 11 | sitia
# Processing Record 33 of Set 11 | ankazoabo
# Processing Record 34 of Set 11 | lashio
# Processing Record 35 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 11 | baghdad
# Processing Record 37 of Set 11 | rafaela
# Processing Record 38 of Set 11 | korla
# Processing Record 39 of Set 11 | ylivieska
# Processing Record 40 of Set 11 | inirida
# Processing Record 41 of Set 11 | atasu
# Processing Record 42 of Set 11 | wad rawah
# Processing Record 43 of Set 11 | anadyr
# Processing Record 44 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 45 of Set 11 | tautira
# Processing Record 46 of Set 11 | warrnambool
# Processing Record 47 of Set 11 | atar
# Processing Record 48 of Set 11 | noumea
# Processing Record 49 of Set 11 | skjervoy
# Processing Record 50 of Set 11 | bubaque
# Processing Record 1 of Set 12 | vila franca do campo
# Processing Record 2 of Set 12 | lichinga
# Processing Record 3 of Set 12 | beder
# Processing Record 4 of Set 12 | cabedelo
# Processing Record 5 of Set 12 | hambantota
# Processing Record 6 of Set 12 | formigine
# Processing Record 7 of Set 12 | puerto colombia
# Processing Record 8 of Set 12 | sillod
# Processing Record 9 of Set 12 | mponela
# Processing Record 10 of Set 12 | comodoro rivadavia
# Processing Record 11 of Set 12 | sumter
# Processing Record 12 of Set 12 | lavrentiya
# Processing Record 13 of Set 12 | azare
# Processing Record 14 of Set 12 | sandwick
# Processing Record 15 of Set 12 | tornio
# Processing Record 16 of Set 12 | cartagena
# Processing Record 17 of Set 12 | pangai
# Processing Record 18 of Set 12 | bay roberts
# Processing Record 19 of Set 12 | gallup
# Processing Record 20 of Set 12 | hovd
# Processing Record 21 of Set 12 | san bartolome de tirajana
# Processing Record 22 of Set 12 | manokwari
# Processing Record 23 of Set 12 | mugur-aksy
# Processing Record 24 of Set 12 | pemangkat
# Processing Record 25 of Set 12 | de-kastri
# Processing Record 26 of Set 12 | merritt island
# Processing Record 27 of Set 12 | santa isabel
# Processing Record 28 of Set 12 | nogliki
# Processing Record 29 of Set 12 | ugoofaaru
# Processing Record 30 of Set 12 | bilma
# Processing Record 31 of Set 12 | ustka
# Processing Record 32 of Set 12 | qeshm
# Processing Record 33 of Set 12 | ornskoldsvik
# Processing Record 34 of Set 12 | mpwapwa
# Processing Record 35 of Set 12 | barra do corda
# Processing Record 36 of Set 12 | cienaga de flores
# City not found. Skipping...
# Processing Record 37 of Set 12 | afmadu
# City not found. Skipping...
# Processing Record 38 of Set 12 | magaria
# Processing Record 39 of Set 12 | labrea
# Processing Record 40 of Set 12 | hirosaki
# Processing Record 41 of Set 12 | cotonou
# Processing Record 42 of Set 12 | ila
# Processing Record 43 of Set 12 | mabua
# Processing Record 44 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 46 of Set 12 | isla mujeres
# Processing Record 47 of Set 12 | perbaungan
# Processing Record 48 of Set 12 | arlit
# Processing Record 49 of Set 12 | agadir
# Processing Record 50 of Set 12 | filadelfia
# Processing Record 1 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 13 | san rafael
# Processing Record 3 of Set 13 | lokoja
# Processing Record 4 of Set 13 | araouane
# Processing Record 5 of Set 13 | calafell
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# **Add the weather data to a new DataFrame**

# %%
weather_data_df = pd.DataFrame(city_data)
weather_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Georgetown   5.4112  100.3354     85.93        81          20
# 1  Puerto Ayora  -0.7393  -90.3518     73.42        85          74
# 2        Bethel  41.3712  -73.4140     15.57        55         100
# 3       Iqaluit  63.7506  -68.5145    -13.27        62          40
# 4    Butaritari   3.0707  172.7902     82.49        72          52
#
#    Wind Speed Country                 Date       Description
# 0        1.01      MY  2022-01-30 02:53:26              haze
# 1        5.93      EC  2022-01-30 02:56:54     broken clouds
# 2        5.01      US  2022-01-30 03:02:18   overcast clouds
# 3        8.99      CA  2022-01-30 03:00:15  scattered clouds
# 4       17.83      KI  2022-01-30 03:05:51     broken clouds

# %% [markdown]
# **Export the DataFrame as WeatherPy_Database.csv into the Weather_Database folder**

# %%
export_data_file = weather_data_df.to_csv("Weather_Database/WeatherPy_Database.csv", index_label = "City_ID")
